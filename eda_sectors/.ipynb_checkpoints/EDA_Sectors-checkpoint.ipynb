# %% [markdown]
# # Sectors EDA #
# *by Rosana de Oliveira Gomes*
#
# In this notebook, we investigate the text extracted by websites associated to Climate Change Mitation by applying NLP and data analysis techniques.
#
# The data used in this project comes from the [ImpactLab](https://impactlab.org) and [DrawDown](https://drawdown.org/sectors/) websites.
#
# In this analysis, you will learn about:
#
# * keyword extraction
# * data Cleaning and preprocessing with NLP
# * assigning categories to text based on a description
# * text data visualization

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Data ##
#
# Getting data from the scraping of the websites.

# %%
df_dd_sectors = pd.read_csv('datasets/dd_sectors.csv')
df_dd_tableofsolutions = pd.read_csv('datasets/dd_tableofsolutions_table.csv')
df_dd_solutions = pd.read_csv('datasets/dd_solutions_data.csv')
df_il_articles = pd.read_csv('datasets/il_articles.csv')
df_il_article_content = pd.read_csv('datasets/il_article_content.csv')

print(f"shape dd_sectors: {df_dd_sectors.shape}", 
      df_dd_sectors.columns)
df_dd_sectors.head(10)
# Out:
# shape dd_sectors: (9, 7) Index(['Unnamed: 0', 'sector', 'url', 'st_value', 'st_unit', 'st_label',
#        'content'],
#       dtype='object')
#    Unnamed: 0                           sector  \
# 0           0                      Electricity
# 1           1  Food, Agriculture, and Land Use
# 2           2                         Industry
# 3           3                   Transportation
# 4           4                        Buildings
# 5           5                       Land Sinks
# 6           6          Coastal and Ocean Sinks
# 7           7                 Engineered Sinks
# 8           8             Health and Education
#
#                                                  url     st_value   st_unit  \
# 0           https://drawdown.org/sectors/electricity  200.6–440.2  Gigatons
# 1  https://drawdown.org/sectors/food-agriculture-...  204.2–273.9  Gigatons
# 2              https://drawdown.org/sectors/industry  128.8–143.8  Gigatons
# 3        https://drawdown.org/sectors/transportation      58–97.4  Gigatons
# 4             https://drawdown.org/sectors/buildings   73.7–141.2  Gigatons
# 5            https://drawdown.org/sectors/land-sinks  243.1–387.8  Gigatons
# 6  https://drawdown.org/sectors/coastal-and-ocean...    1.07–1.48  Gigatons
# 7      https://drawdown.org/sectors/engineered-sinks    2.22–4.39  Gigatons
# 8  https://drawdown.org/sectors/health-and-education        85.42  Gigatons
#
#                                          st_label  \
# 0  CO2 EquivalentReduced / Sequestered(2020–2050)
# 1  CO2 EquivalentReduced / Sequestered(2020–2050)
# 2  CO2 EquivalentReduced / Sequestered(2020–2050)
# 3  CO2 EquivalentReduced / Sequestered(2020–2050)
# 4  CO2 EquivalentReduced / Sequestered(2020–2050)
# 5  CO2 EquivalentReduced / Sequestered(2020–2050)
# 6  CO2 EquivalentReduced / Sequestered(2020–2050)
# 7  CO2 EquivalentReduced / Sequestered(2020–2050)
# 8  CO2 EquivalentReduced / Sequestered(2020–2050)
#
#                                              content
# 0  \nElectricity is particles in motion—a flow of...
# 1  \nHuman activity has transformed a significant...
# 2  \nFrom concrete to computers, cars to clothing...
# 3  \nGetting people or things from point A to poi...
# 4  \nInside is where most people are most of the ...
# 5  \nLand is a critical component of the climate ...
# 6  \nOurs is a water world. Though Earth has a la...
# 7  \nCan human engineering play a supporting role...
# 8  \nClimate and social systems are profoundly co...

# %%
print(f"shape dd_tableofsolutions: {df_dd_tableofsolutions.shape}")
df_dd_tableofsolutions.columns
df_dd_tableofsolutions.head(10)
# Out:
# shape dd_tableofsolutions: (82, 4)
#                       Solution                Sector(s)  Scenario 1 *  \
# 0            Smart Thermostats  Electricity / Buildings          6.99
# 1  Building Automation Systems  Electricity / Buildings          6.47
# 2                 LED Lighting              Electricity         16.07
# 3                   Insulation  Electricity / Buildings         16.97
# 4                Dynamic Glass  Electricity / Buildings          0.29
# 5       High-Performance Glass  Electricity / Buildings         10.04
# 6         Green and Cool Roofs  Electricity / Buildings          0.60
# 7             District Heating  Electricity / Buildings          6.28
# 8   High-Efficiency Heat Pumps  Electricity / Buildings          4.16
# 9              Solar Hot Water  Electricity / Buildings          3.59
#
#    Scenario 2 *
# 0          7.40
# 1         10.48
# 2         17.53
# 3         19.01
# 4          0.47
# 5         12.63
# 6          1.10
# 7          9.85
# 8          9.29
# 9         14.29

# %%
print(f"shape dd_solutions: {df_dd_solutions.shape}", df_dd_solutions.columns)
df_dd_solutions.head(10)
# Out:
# shape dd_solutions: (82, 23) Index(['Unnamed: 0', 'title', 'node1', 'area', 'node2', 'url', 'st_value1',
#        'st_unit1', 'st_label1', 'st_value2', 'st_unit2', 'st_label2',
#        'st_value3', 'st_unit3', 'st_label3', 'st_value4', 'st_unit4',
#        'st_label4', 'short_def', 'summary', 'impact', 'tech_link',
#        'tech_summary'],
#       dtype='object')
#    Unnamed: 0                           title             node1  \
# 0           0  Abandoned Farmland Restoration        Land Sinks
# 1           1              Alternative Cement          Industry
# 2           2        Alternative Refrigerants          Industry
# 3           3               Bamboo Production        Land Sinks
# 4           4          Bicycle Infrastructure    Transportation
# 5           5              Biochar Production  Engineered Sinks
# 6           6              Biogas for Cooking         Buildings
# 7           7                   Biomass Power       Electricity
# 8           8                     Bioplastics          Industry
# 9           9     Building Automation Systems       Electricity
#
#              area                    node2  \
# 0   Support Sinks        Use Degraded Land
# 1  Reduce Sources        Improve Materials
# 2  Reduce Sources     Address Refrigerants
# 3   Support Sinks        Use Degraded Land
# 4  Reduce Sources    Shift to Alternatives
# 5   Support Sinks  Remove and Store Carbon
# 6  Reduce Sources     Shift Energy Sources
# 7  Reduce Sources         Shift Production
# 8  Reduce Sources        Improve Materials
# 9  Reduce Sources       Enhance Efficiency
#
#                                                  url    st_value1  st_unit1  \
# 0  https://drawdown.org/solutions/abandoned-farml...  12.48–20.32  Gigatons
# 1  https://drawdown.org/solutions/alternative-cement    7.98–16.1  Gigatons
# 2  https://drawdown.org/solutions/alternative-ref...  43.53–50.53  Gigatons
# 3   https://drawdown.org/solutions/bamboo-production   8.27–21.31  Gigatons
# 4  https://drawdown.org/solutions/bicycle-infrast...    2.56–6.65  Gigatons
# 5  https://drawdown.org/solutions/biochar-production    2.22–4.39  Gigatons
# 6  https://drawdown.org/solutions/biogas-for-cooking     4.65–9.7  Gigatons
# 7       https://drawdown.org/solutions/biomass-power    2.52–3.57  Gigatons
# 8         https://drawdown.org/solutions/bioplastics     0.96–3.8  Gigatons
# 9  https://drawdown.org/solutions/building-automa...   6.47–10.48  Gigatons
#
#                                         st_label1       st_value2  ...  \
# 0  CO2 EquivalentReduced / Sequestered(2020–2050)   $98.16–159.91  ...
# 1  CO2 EquivalentReduced / Sequestered(2020–2050)         $-63.46  ...
# 2  CO2 EquivalentReduced / Sequestered(2020–2050)               0  ...
# 3  CO2 EquivalentReduced / Sequestered(2020–2050)   $52.25–161.94  ...
# 4  CO2 EquivalentReduced / Sequestered(2020–2050)    $-7.54–-2.66  ...
# 5  CO2 EquivalentReduced / Sequestered(2020–2050)   $195.87–383.3  ...
# 6  CO2 EquivalentReduced / Sequestered(2020–2050)    $24.72–51.59  ...
# 7  CO2 EquivalentReduced / Sequestered(2020–2050)    $51.12–62.37  ...
# 8  CO2 EquivalentReduced / Sequestered(2020–2050)    $25.47–88.15  ...
# 9  CO2 EquivalentReduced / Sequestered(2020–2050)  $225.23–312.32  ...
#
#        st_unit3                        st_label3   st_value4      st_unit4  \
# 0  Trillion $US  Lifetime NetOperational Savings  $2.66–4.34  Trillion $US
# 1             0                                0           0             0
# 2             0                                0           0             0
# 3  Trillion $US  Lifetime NetOperational Savings  $1.71–4.35  Trillion $US
# 4  Trillion $US  Lifetime NetOperational Savings           0             0
# 5  Trillion $US  Lifetime NetOperational Savings           0             0
# 6   Billion $US  Lifetime NetOperational Savings           0             0
# 7   Billion $US  Lifetime NetOperational Savings           0             0
# 8   Billion $US  Lifetime NetOperational Savings           0             0
# 9  Trillion $US  Lifetime NetOperational Savings           0             0
#
#             st_label4                                          short_def  \
# 0  LifetimeNet Profit  Degraded farmland is often abandoned, but need...
# 1                   0                                                NaN
# 2                   0  Fluorinated gases are not the only refrigerant...
# 3  LifetimeNet Profit  Bamboo rapidly sequesters carbon in biomass an...
# 4                   0  Bicycles offer an alternative to cars and foss...
# 5                   0  Biomass slowly baked in the absence of oxygen ...
# 6                   0  Anaerobic digesters process backyard or farmya...
# 7                   0  Biomass feedstock can replace fossil fuels for...
# 8                   0  Most plastics are made from fossil fuels, but ...
# 9                   0  These systems can control heating, cooling, li...
#
#                                              summary  \
# 0  Solution Summary*Around the world, farmers are...
# 1  Solution Summary*Cement is a vital source of s...
# 2  Solution SummaryThis is a new solution; a summ...
# 3  Solution Summary*In the Philippine creation st...
# 4  Solution Summary*Bicycles are on the rise as c...
# 5  Solution Summary*In ancient Amazonia, the wast...
# 6  Solution SummaryThis is a new solution; a summ...
# 7  Solution Summary*Biomass energy is a “bridge” ...
# 8  Solution Summary*Globally, we produce roughly ...
# 9  Solution Summary*Energy courses through buildi...
#
#                                               impact  \
# 0  Impact: Currently, 0.4 billion hectares of far...
# 1                                                NaN
# 2  Impact: Pursuant to the Kigali Accord signed i...
# 3  Impact: Bamboo is planted on 33.52million hect...
# 4  Impact: In 2018, just under 3 percent of urban...
# 5  Impact: Biochar can produce 2.2–4.4 gigatons o...
# 6  Impact: Small biogas reactors can be installed...
# 7  Impact: This analysis assumes all biomass used...
# 8  Impact: We estimate the total production of pl...
# 9  Impact: Building Automation Systems (BAS) can ...
#
#                                            tech_link  \
# 0  https://drawdown.org/solutions/abandoned-farml...
# 1  https://drawdown.org/solutions/alternative-cem...
# 2  https://drawdown.org/solutions/alternative-ref...
# 3  https://drawdown.org/solutions/bamboo-producti...
# 4  https://drawdown.org/solutions/bicycle-infrast...
# 5  https://drawdown.org/solutions/biochar-product...
# 6  https://drawdown.org/solutions/biogas-for-cook...
# 7  https://drawdown.org/solutions/biomass-power/t...
# 8  https://drawdown.org/solutions/bioplastics/tec...
# 9  https://drawdown.org/solutions/building-automa...
#
#                                         tech_summary
# 0  Project Drawdown describes abandoned farmland ...
# 1  Project Drawdown defines alternative cement as...
# 2  Project Drawdown defines alternative refrigera...
# 3  Project Drawdown defines bamboo production as ...
# 4  Project Drawdown defines bicycle infrastructur...
# 5  Project Drawdown defines biochar as a bioseque...
# 6  Project Drawdown defines biogas for cooking as...
# 7  Project Drawdown defines biomass power as the ...
# 8  Project Drawdown defines bioplastics as replac...
# 9  Project Drawdown defines building automation s...
#
# [10 rows x 23 columns]

# %%
print(f"shape df_il_articles: {df_il_articles.shape}", df_il_articles.columns)
df_il_articles.head(10)
# Out:
# shape df_il_articles: (54, 8) Index(['Unnamed: 0', 'category', 'url', 'citation', 'link', 'sumary', 'type',
#        'pub_date'],
#       dtype='object')
#    Unnamed: 0        category  \
# 0           0  climateScience
# 1           1  climateScience
# 2           2  climateScience
# 3           3  climateScience
# 4           4  climateScience
# 5           5      socialCost
# 6           6      socialCost
# 7           7      socialCost
# 8           8      socialCost
# 9           9      socialCost
#
#                                                  url  \
# 0  https://impactlab.org/research-area/climate-sc...
# 1  https://impactlab.org/research-area/climate-sc...
# 2  https://impactlab.org/research-area/climate-sc...
# 3  https://impactlab.org/research-area/climate-sc...
# 4  https://impactlab.org/research-area/climate-sc...
# 5   https://impactlab.org/research-area/social-cost/
# 6   https://impactlab.org/research-area/social-cost/
# 7   https://impactlab.org/research-area/social-cost/
# 8   https://impactlab.org/research-area/social-cost/
# 9   https://impactlab.org/research-area/social-cost/
#
#                                             citation  \
# 0  Dawei Li, Jiacan Yuan, and Robert (Bob) Kopp. ...
# 1  Kopp, R. E., DeConto, R. M., Bader, D. A., Hay...
# 2  USGCRP, 2017: Climate Science Special Report: ...
# 3            U.S. Government Accountability Office\n
# 4  Yuan, J., Stein, M. L., & Kopp, R. E. (2020). ...
# 5  Carleton, Tamma and Greenstone, Michael, Updat...
# 6  Ciscar, J.-C., Rising, J., Kopp, R. E., & Feye...
# 7  Duffy, P. B., Field, C.B., Diffenbaugh, N. S.,...
# 8  R. Revesz, M. Greenstone, M. Hanemann, M. Live...
# 9  Presentation by Michael Greenstone and the Cli...
#
#                                                 link  \
# 0  https://impactlab.org/research/escalating-glob...
# 1  https://impactlab.org/research/evolving-unders...
# 2  https://impactlab.org/research/climate-science...
# 3  https://impactlab.org/research/climate-change-...
# 4  https://impactlab.org/research/the-evolving-di...
# 5  https://impactlab.org/research/updating-the-un...
# 6  https://impactlab.org/research/assessing-futur...
# 7  https://impactlab.org/research/0-review-streng...
# 8  https://impactlab.org/research/best-cost-estim...
# 9  https://impactlab.org/research/assessing-appro...
#
#                                               sumary             type  \
# 0                                                NaN  Journal Article
# 1  This study links a framework for global and lo...  Journal Article
# 2  Lab co-director Robert Kopp helped write the “...  Journal Article
# 3  The GAO's new report draws heavily from two na...           Report
# 4  The impacts of heat waves in a warming climate...  Journal Article
# 5  This paper outlines a two-step process to retu...    Working Paper
# 6                                                NaN  Journal Article
# 7  We assess scientific evidence that has emerged...  Journal Article
# 8  Prominent economists and lawyers highlight the...  Journal Article
# 9  Michael Greenstone describes pathbreaking new ...           Report
#
#                       pub_date
# 0      Published March 7, 2020
# 1  Published December 13, 2017
# 2   Published November 3, 2017
# 3   Published October 24, 2017
# 4  Published September 9, 2020
# 5   Published January 14, 2021
# 6      Published July 26, 2019
# 7  Published December 14, 2018
# 8    Published August 18, 2017
# 9        Published May 5, 2017

# %%
print(f"shape df_il_article_content: {df_il_article_content.shape}", df_il_article_content.columns)
df_il_article_content.head(10)
# Out:
# shape df_il_article_content: (54, 10) Index(['Unnamed: 0', 'abstract', 'articleType', 'article_links', 'citation',
#        'content', 'download_link', 'header', 'pub_date', 'url'],
#       dtype='object')
#    Unnamed: 0                                           abstract  \
# 0           0  Heat stress harms human health, agriculture, a...
# 1           1  Mechanisms such as ice-shelf hydrofracturing a...
# 2           2  This assessment concludes, based on extensive ...
# 3           3                                                NaN
# 4           4  The impacts of heat waves in a warming climate...
# 5           5  This paper outlines a two-step process to retu...
# 6           6  Climate change will impact many economic secto...
# 7           7  We assess scientific evidence that has emerged...
# 8           8  Despite the Trump administration’s decision to...
# 9           9  Michael Greenstone describes pathbreaking new ...
#
#        articleType                                      article_links  \
# 0  Journal Article  ['https://iopscience.iop.org/article/10.1088/1...
# 1  Journal Article  ['http://onlinelibrary.wiley.com/doi/10.1002/2...
# 2  Journal Article          ['https://science2017.globalchange.gov/']
# 3           Report                                                 []
# 4  Journal Article  ['https://doi.org/10.1029/2019JD032100', 'http...
# 5    Working Paper  ['https://ssrn.com/abstract=3764255', 'https:/...
# 6  Journal Article  ['https://iopscience.iop.org/article/10.1088/1...
# 7  Journal Article  ['http://science.sciencemag.org/content/early/...
# 8  Journal Article  ['http://science.sciencemag.org/content/357/63...
# 9           Report  ['http://sites.nationalacademies.org/DBASSE/BE...
#
#                                             citation  \
# 0  \nDawei Li, Jiacan Yuan, and Robert (Bob) Kopp...
# 1  \nKopp, R. E., DeConto, R. M., Bader, D. A., H...
# 2  \nUSGCRP, 2017: Climate Science Special Report...
# 3          \nU.S. Government Accountability Office\n
# 4  \nYuan, J., Stein, M. L., & Kopp, R. E. (2020)...
# 5  \nCarleton, Tamma and Greenstone, Michael, Upd...
# 6  \nCiscar, J.-C., Rising, J., Kopp, R. E., & Fe...
# 7  \nDuffy, P. B., Field, C.B., Diffenbaugh, N. S...
# 8  \nR. Revesz, M. Greenstone, M. Hanemann, M. Li...
# 9  \nPresentation by Michael Greenstone and the C...
#
#                                              content  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  \n\n\nThe social cost of carbon (SCC), the tot...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                        download_link  \
# 0  https://impactlab.org/wp-content/uploads/2017/...
# 1  https://impactlab.org/wp-content/uploads/2017/...
# 2  https://impactlab.org/wp-content/uploads/2017/...
# 3           http://www.gao.gov/assets/690/687466.pdf
# 4           http://www.gao.gov/assets/690/687466.pdf
# 5  https://impactlab.org/wp-content/uploads/2021/...
# 6  https://impactlab.org/wp-content/uploads/2021/...
# 7  https://impactlab.org/wp-content/uploads/2021/...
# 8  https://impactlab.org/wp-content/uploads/2021/...
# 9  https://impactlab.org/wp-content/uploads/2021/...
#
#                                               header  \
# 0  Escalating Global Exposure to Compound Heat-Hu...
# 1  Evolving Understanding of Antarctic Ice-Sheet ...
# 2  Climate Science Special Report: Fourth Nationa...
# 3  Climate Change: Information on Potential Econo...
# 4  The Evolving Distribution of Relative Humidity...
# 5  Updating the United States Government’s  Socia...
# 6  Assessing future climate change impacts in the...
# 7  Strengthened scientific support for the Endang...
# 8             Best cost estimate of greenhouse gases
# 9  Assessing Approaches to Updating the Social Co...
#
#                       pub_date  \
# 0      Published March 7, 2020
# 1  Published December 13, 2017
# 2   Published November 3, 2017
# 3   Published October 24, 2017
# 4  Published September 9, 2020
# 5   Published January 14, 2021
# 6      Published July 26, 2019
# 7  Published December 14, 2018
# 8    Published August 18, 2017
# 9        Published May 5, 2017
#
#                                                  url
# 0  https://impactlab.org/research/escalating-glob...
# 1  https://impactlab.org/research/evolving-unders...
# 2  https://impactlab.org/research/climate-science...
# 3  https://impactlab.org/research/climate-change-...
# 4  https://impactlab.org/research/the-evolving-di...
# 5  https://impactlab.org/research/updating-the-un...
# 6  https://impactlab.org/research/assessing-futur...
# 7  https://impactlab.org/research/0-review-streng...
# 8  https://impactlab.org/research/best-cost-estim...
# 9  https://impactlab.org/research/assessing-appro...

# %% [markdown]
# Clearning the datasets to contain only relevant columns:

# %%
df_dd_sectors = df_dd_sectors.drop(columns=['Unnamed: 0', 'url', 'st_value',  
                                            'st_unit',  'st_label'])

df_dd_solutions = df_dd_solutions.drop(columns=['Unnamed: 0', 'url', 'st_value1', 
                                                'st_unit1', 'st_value2', 'st_unit2', 
                                                'st_label2', 'st_value3', 'st_unit3', 
                                                'st_label3', 'st_value4', 'st_unit4', 
                                                'st_label4', 'tech_link'])

df_il_articles = df_il_articles.drop(columns=['Unnamed: 0', 'url', 'citation', 
                                              'link', 'type','pub_date'])

df_il_article_content = df_il_article_content.drop(columns=['Unnamed: 0', 'articleType',
                                                            'article_links', 'citation',
                                                            'download_link', 'pub_date', 
                                                            'url'])

print(df_dd_sectors)
print(df_dd_solutions)
print(df_il_articles)
print(df_il_article_content)
# Out:
#                             sector  \
# 0                      Electricity
# 1  Food, Agriculture, and Land Use
# 2                         Industry
# 3                   Transportation
# 4                        Buildings
# 5                       Land Sinks
# 6          Coastal and Ocean Sinks
# 7                 Engineered Sinks
# 8             Health and Education
#
#                                              content
# 0  \nElectricity is particles in motion—a flow of...
# 1  \nHuman activity has transformed a significant...
# 2  \nFrom concrete to computers, cars to clothing...
# 3  \nGetting people or things from point A to poi...
# 4  \nInside is where most people are most of the ...
# 5  \nLand is a critical component of the climate ...
# 6  \nOurs is a water world. Though Earth has a la...
# 7  \nCan human engineering play a supporting role...
# 8  \nClimate and social systems are profoundly co...
#                                 title           node1            area  \
# 0      Abandoned Farmland Restoration      Land Sinks   Support Sinks
# 1                  Alternative Cement        Industry  Reduce Sources
# 2            Alternative Refrigerants        Industry  Reduce Sources
# 3                   Bamboo Production      Land Sinks   Support Sinks
# 4              Bicycle Infrastructure  Transportation  Reduce Sources
# ..                                ...             ...             ...
# 77       Utility-Scale Energy Storage     Electricity  Reduce Sources
# 78  Utility-Scale Solar Photovoltaics     Electricity  Reduce Sources
# 79                    Walkable Cities  Transportation  Reduce Sources
# 80                    Waste-to-Energy     Electricity  Reduce Sources
# 81      Water Distribution Efficiency     Electricity  Reduce Sources
#
#                     node2                                       st_label1  \
# 0       Use Degraded Land  CO2 EquivalentReduced / Sequestered(2020–2050)
# 1       Improve Materials  CO2 EquivalentReduced / Sequestered(2020–2050)
# 2    Address Refrigerants  CO2 EquivalentReduced / Sequestered(2020–2050)
# 3       Use Degraded Land  CO2 EquivalentReduced / Sequestered(2020–2050)
# 4   Shift to Alternatives  CO2 EquivalentReduced / Sequestered(2020–2050)
# ..                    ...                                             ...
# 77     Improve the System                                               0
# 78       Shift Production  CO2 EquivalentReduced / Sequestered(2020–2050)
# 79  Shift to Alternatives  CO2 EquivalentReduced / Sequestered(2020–2050)
# 80       Shift Production  CO2 EquivalentReduced / Sequestered(2020–2050)
# 81     Enhance Efficiency  CO2 EquivalentReduced / Sequestered(2020–2050)
#
#                                             short_def  \
# 0   Degraded farmland is often abandoned, but need...
# 1                                                 NaN
# 2   Fluorinated gases are not the only refrigerant...
# 3   Bamboo rapidly sequesters carbon in biomass an...
# 4   Bicycles offer an alternative to cars and foss...
# ..                                                ...
# 77  Large-scale energy storage ensures electricity...
# 78  Solar photovoltaics can be used at utility-sca...
# 79  Walkable cities use planning, design, and dens...
# 80  Waste-to-energy processes (incineration, gasif...
# 81  Pumping water requires enormous amounts of ele...
#
#                                               summary  \
# 0   Solution Summary*Around the world, farmers are...
# 1   Solution Summary*Cement is a vital source of s...
# 2   Solution SummaryThis is a new solution; a summ...
# 3   Solution Summary*In the Philippine creation st...
# 4   Solution Summary*Bicycles are on the rise as c...
# ..                                                ...
# 77  Solution Summary*Utilities have long operated ...
# 78  Solution Summary*The sun provides a virtually ...
# 79  Solution Summary*Walkable cities prioritize tw...
# 80  Solution Summary*In a sustainable world, waste...
# 81  Solution Summary*Pumping water from source to ...
#
#                                                impact  \
# 0   Impact: Currently, 0.4 billion hectares of far...
# 1                                                 NaN
# 2   Impact: Pursuant to the Kigali Accord signed i...
# 3   Impact: Bamboo is planted on 33.52million hect...
# 4   Impact: In 2018, just under 3 percent of urban...
# ..                                                ...
# 77  Impact: Taken on its own, the use of energy st...
# 78  Impact: Currently just over 1 percent of globa...
# 79  Impact: The six dimensions of the built enviro...
# 80  Impact: The negative externalities of waste-to...
# 81  Impact: Modeling only the impact of pressure m...
#
#                                          tech_summary
# 0   Project Drawdown describes abandoned farmland ...
# 1   Project Drawdown defines alternative cement as...
# 2   Project Drawdown defines alternative refrigera...
# 3   Project Drawdown defines bamboo production as ...
# 4   Project Drawdown defines bicycle infrastructur...
# ..                                                ...
# 77  Project Drawdown defines utility-scale energy ...
# 78  Project Drawdown considers utility-scale solar...
# 79  Project Drawdown defines walkable cities as de...
# 80  Project Drawdown defines waste-to-energy as th...
# 81  Project Drawdown defines water distribution as...
#
# [82 rows x 9 columns]
#           category                                             sumary
# 0   climateScience                                                NaN
# 1   climateScience  This study links a framework for global and lo...
# 2   climateScience  Lab co-director Robert Kopp helped write the “...
# 3   climateScience  The GAO's new report draws heavily from two na...
# 4   climateScience  The impacts of heat waves in a warming climate...
# 5       socialCost  This paper outlines a two-step process to retu...
# 6       socialCost                                                NaN
# 7       socialCost  We assess scientific evidence that has emerged...
# 8       socialCost  Prominent economists and lawyers highlight the...
# 9       socialCost  Michael Greenstone describes pathbreaking new ...
# 10      socialCost  Unifies the discrepancies between the micro-le...
# 11      socialCost  Combines the latest climate models, state-of-t...
# 12      socialCost  The social cost of carbon (SCC) is a crucial t...
# 13          health  This paper estimates that the release of an ad...
# 14          health                                                NaN
# 15          health  The GAO's new report draws heavily from two na...
# 16          health  Spatially explicit, probabilistic, and empiric...
# 17          health  There is a stark inequality in the effect of a...
# 18          health  For centuries, thinkers have considered whethe...
# 19     agriculture  Warming temperatures over the last 30 years is...
# 20     agriculture  A key strategy for agriculture to adapt to cli...
# 21     agriculture  The GAO's new report draws heavily from two na...
# 22     agriculture  Spatially explicit, probabilistic, and empiric...
# 23     agriculture  For centuries, thinkers have considered whethe...
# 24     agriculture  Combines the latest climate models, state-of-t...
# 25     agriculture  The American Climate Prospectus (ACP) provides...
# 26          labour  The GAO's new report draws heavily from two na...
# 27          labour  Unifies the discrepancies between the micro-le...
# 28          labour  Spatially explicit, probabilistic, and empiric...
# 29          labour  For centuries, thinkers have considered whethe...
# 30          labour  Combines the latest climate models, state-of-t...
# 31          energy  In this report, commissioned by the Department...
# 32          energy  The GAO's new report draws heavily from two na...
# 33          energy  Spatially explicit, probabilistic, and empiric...
# 34          energy  The American Climate Prospectus (ACP) provides...
# 35          energy  For centuries, thinkers have considered whethe...
# 36        conflict  If a month is 1 degree Celsius warmer than nor...
# 37        conflict  Review of the current literature on climate an...
# 38        conflict  Examines 50 rigorous quantitative studies on t...
# 39        conflict  Spatially explicit, probabilistic, and empiric...
# 40        conflict  For centuries, thinkers have considered whethe...
# 41        conflict  Finds that unearned income and excess infant m...
# 42         coastal  This study develops a method to estimate past,...
# 43         coastal  Future sea level rise (SLR) poses serious thre...
# 44         coastal  This study links a framework for global and lo...
# 45         coastal  The amplification of flood frequencies by sea ...
# 46         coastal  Global set of local sea-level projections to i...
# 47         coastal  Finds that unearned income and excess infant m...
# 48         coastal  Estimates the extent of adaptation to tropical...
# 49       migration  For centuries, thinkers have considered whethe...
# 50       migration  Evidence increasingly suggests that as climate...
# 51       migration  Combines the latest climate models, state-of-t...
# 52       migration  The American Climate Prospectus (ACP) provides...
# 53       migration  Investigates the effects of variations in temp...
#                                              abstract  \
# 0   Heat stress harms human health, agriculture, a...
# 1   Mechanisms such as ice-shelf hydrofracturing a...
# 2   This assessment concludes, based on extensive ...
# 3                                                 NaN
# 4   The impacts of heat waves in a warming climate...
# 5   This paper outlines a two-step process to retu...
# 6   Climate change will impact many economic secto...
# 7   We assess scientific evidence that has emerged...
# 8   Despite the Trump administration’s decision to...
# 9   Michael Greenstone describes pathbreaking new ...
# 10  Growing evidence demonstrates that climatic co...
# 11  Climate change threatens the economy of the Un...
# 12  The social cost of carbon (SCC) is a crucial t...
# 13  This paper develops the first globally compreh...
# 14  Temperature and relative humidity have opposin...
# 15                                                NaN
# 16  Estimates of climate change damage are central...
# 17  This paper reveals a stark inequality in the e...
# 18  For centuries, thinkers have considered whethe...
# 19  More than three quarters of the world’s suicid...
# 20  A key strategy for agriculture to adapt to cli...
# 21                                                NaN
# 22  Estimates of climate change damage are central...
# 23  For centuries, thinkers have considered whethe...
# 24  Climate change threatens the economy of the Un...
# 25  The United States faces a range of economic ri...
# 26                                                NaN
# 27  Growing evidence demonstrates that climatic co...
# 28  Estimates of climate change damage are central...
# 29  For centuries, thinkers have considered whethe...
# 30  Climate change threatens the economy of the Un...
# 31  Electric utilities, system operators and regul...
# 32                                                NaN
# 33  Estimates of climate change damage are central...
# 34  The United States faces a range of economic ri...
# 35  For centuries, thinkers have considered whethe...
# 36  Linkages between climate and mental health are...
# 37  We review the emerging literature on climate a...
# 38  Are violent conflict and socio-political stabi...
# 39  Estimates of climate change damage are central...
# 40  For centuries, thinkers have considered whethe...
# 41  The immediate physical damages caused by envir...
# 42  We develop a method to estimate past, present,...
# 43  Despite considerable advances in process under...
# 44  Mechanisms such as ice-shelf hydrofracturing a...
# 45  The amplification of flood frequencies by sea ...
# 46  Sea-level rise due to both climate change and ...
# 47  The immediate physical damages caused by envir...
# 48  Understanding the feasibility and cost of adap...
# 49  For centuries, thinkers have considered whethe...
# 50  Evidence increasingly suggests that as climate...
# 51  Climate change threatens the economy of the Un...
# 52  The United States faces a range of economic ri...
# 53  We present a microlevel study to simultaneousl...
#
#                                               content  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   \n\n\nThe social cost of carbon (SCC), the tot...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  \n\n\nThis prospectus is based on a critically...
# 12                                                NaN
# 13  \n\n\nResearch Summary\nCommunities are alread...
# 14                                                NaN
# 15                                                NaN
# 16  \n\n\nDATA DOWNLOAD\nThis data is provided for...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  \n\n\nDATA DOWNLOAD\nThis data is provided for...
# 23                                                NaN
# 24  \n\n\nThis prospectus is based on a critically...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  \n\n\nDATA DOWNLOAD\nThis data is provided for...
# 29                                                NaN
# 30  \n\n\nThis prospectus is based on a critically...
# 31                                                NaN
# 32                                                NaN
# 33  \n\n\nDATA DOWNLOAD\nThis data is provided for...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  \n\n\nDATA DOWNLOAD\nThis data is provided for...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  \n\n\nThis prospectus is based on a critically...
# 52                                                NaN
# 53                                                NaN
#
#                                                header
# 0   Escalating Global Exposure to Compound Heat-Hu...
# 1   Evolving Understanding of Antarctic Ice-Sheet ...
# 2   Climate Science Special Report: Fourth Nationa...
# 3   Climate Change: Information on Potential Econo...
# 4   The Evolving Distribution of Relative Humidity...
# 5   Updating the United States Government’s  Socia...
# 6   Assessing future climate change impacts in the...
# 7   Strengthened scientific support for the Endang...
# 8              Best cost estimate of greenhouse gases
# 9   Assessing Approaches to Updating the Social Co...
# 10  Global Non-Linear Effect of Temperature on Eco...
# 11  Economic Risks of Climate Change: An American ...
# 12      Using and Improving the Social Cost of Carbon
# 13  Valuing the Global Mortality Consequences of C...
# 14  Assessment of the combination of temperature a...
# 15  Climate Change: Information on Potential Econo...
# 16  Estimating Economic Damage from Climate Change...
# 17         Weather, Climate Change and Death in India
# 18             Social and economic impacts of climate
# 19  Crop-damaging temperatures increase suicide ra...
# 20  Crop switching reduces agricultural losses fro...
# 21  Climate Change: Information on Potential Econo...
# 22  Estimating Economic Damage from Climate Change...
# 23             Social and economic impacts of climate
# 24  Economic Risks of Climate Change: An American ...
# 25  American Climate Prospectus: Economic Risks in...
# 26  Climate Change: Information on Potential Econo...
# 27  Global Non-Linear Effect of Temperature on Eco...
# 28  Estimating Economic Damage from Climate Change...
# 29             Social and economic impacts of climate
# 30  Economic Risks of Climate Change: An American ...
# 31  Assessing the Effect of Rising Temperatures: T...
# 32  Climate Change: Information on Potential Econo...
# 33  Estimating Economic Damage from Climate Change...
# 34  American Climate Prospectus: Economic Risks in...
# 35             Social and economic impacts of climate
# 36  Higher temperatures increase suicide rates in ...
# 37                               Climate and Conflict
# 38  Climate, Conflict, and Social Stability: What ...
# 39  Estimating Economic Damage from Climate Change...
# 40             Social and economic impacts of climate
# 41  Destruction, Disinvestment, and Death: Economi...
# 42  Combined Modeling of US Fluvial, Pluvial, and ...
# 43  Ice sheet contributions to future sea-level ri...
# 44  Evolving Understanding of Antarctic Ice-Sheet ...
# 45  Amplification of flood frequencies with local ...
# 46  Probabilistic 21st and 22nd century sea-level ...
# 47  Destruction, Disinvestment, and Death: Economi...
# 48  Adaptation to Cyclone Risk: Evidence from the ...
# 49             Social and economic impacts of climate
# 50  Potentially Extreme Population Displacement an...
# 51  Economic Risks of Climate Change: An American ...
# 52  American Climate Prospectus: Economic Risks in...
# 53  Nonlinear Permanent Migration Response to Clim...

# %% [markdown]
# ## Text Cleaning ##
#
# Steps for typical NLP preprocessing to be applied to the title and summary of service opportunities.
#
# Let's start with importing relevant NLP libraries

# %%
import contractions
import string
import nltk
import regex as re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from spellchecker import SpellChecker
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /home/rosana/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/rosana/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/rosana/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/rosana/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Next, let's assingn new columns to a copy of the original dataframe, in order to store the preprocessed text of the `title` and `summary` columns.

# %% [markdown]
# **Step 1:** Contraction Mapping / Expanding Contractions

# %% [markdown]
# **Step 2:** Tokenization

# %% [markdown]
# **Step 3:** Lowercasing

# %% [markdown]
# **Step 4:** Spell Checking

# %% [markdown]
# **Step 5:** Removing ‘Stop Words’

# %% [markdown]
# **Step 6:** Stemming/Lemmatization

# %%
# Preprocessing function

def text_preprocessing(text, spelling=False):
    '''
    NLP preprocessing steps in a given dataframe and returns a preprocessed dataframe
    1. Remove contractions
    2. Tokenization
    3. Lowercasing
    4. Remove punctuation
    5. Remove stopwords
    6. Replace misspelled words
    7. Lemmatization
    
    Arguments:
    `descriptions`: descriptions to be preprocessed
    '''
    
    # 
    
    # Make sure we have a column of a data frame as input
    text = pd.Index(text).fillna('')
    
    # 1. Removing contractions
    preprocessed = text.map(lambda x: [contractions.fix(word) for word in x.split()])
    preprocessed = preprocessed.map(lambda x: ' '.join(w for w in x))
    
    # 2. Tokenization
    preprocessed = preprocessed.map(word_tokenize)
    
    # 3. Set all words to lower case
    preprocessed = preprocessed.map(lambda x: [word.lower() for word in x])
    
    # 4. Remove punctuation
    punc = string.punctuation
    preprocessed = preprocessed.map(lambda x: [word for word in x if word not in punc])
    
    # 5. Remove stopwords
    stop_words = set(stopwords.words('english'))
    preprocessed = preprocessed.map(lambda x: [word for word in x if word not in stop_words])
    
    # 6. Replace misspelling
    if spelling:
        spell = SpellChecker()
        preprocessed = preprocessed.map(lambda x: [spell.correction(word) for word in x])
  
    # 7. Lemmatization
    
    preprocessed = preprocessed.map(nltk.tag.pos_tag)

    def get_wordnet_pos(tag):
        if tag.startswith('J'):
            return wordnet.ADJ
        elif tag.startswith('V'):
            return wordnet.VERB
        elif tag.startswith('N'):
            return wordnet.NOUN
        elif tag.startswith('R'):
            return wordnet.ADV
        else:
            return wordnet.NOUN

    preprocessed = preprocessed.map(lambda x: [(word, get_wordnet_pos(pos_tag)) 
                                               for (word, pos_tag) in x])
    
    wnl = WordNetLemmatizer()
    preprocessed = preprocessed.map(lambda x: [wnl.lemmatize(word, tag) 
                                               for word, tag in x])
#    now = datetime.now()

#    print("Current Time =", now)
    return preprocessed

# %%
df_dd_sectors.head()
# Out:
#                             sector  \
# 0                      Electricity
# 1  Food, Agriculture, and Land Use
# 2                         Industry
# 3                   Transportation
# 4                        Buildings
#
#                                              content
# 0  \nElectricity is particles in motion—a flow of...
# 1  \nHuman activity has transformed a significant...
# 2  \nFrom concrete to computers, cars to clothing...
# 3  \nGetting people or things from point A to poi...
# 4  \nInside is where most people are most of the ...

# %%
df_dd_solutions.head()
# Out:
#                             title           node1            area  \
# 0  Abandoned Farmland Restoration      Land Sinks   Support Sinks
# 1              Alternative Cement        Industry  Reduce Sources
# 2        Alternative Refrigerants        Industry  Reduce Sources
# 3               Bamboo Production      Land Sinks   Support Sinks
# 4          Bicycle Infrastructure  Transportation  Reduce Sources
#
#                    node2                                       st_label1  \
# 0      Use Degraded Land  CO2 EquivalentReduced / Sequestered(2020–2050)
# 1      Improve Materials  CO2 EquivalentReduced / Sequestered(2020–2050)
# 2   Address Refrigerants  CO2 EquivalentReduced / Sequestered(2020–2050)
# 3      Use Degraded Land  CO2 EquivalentReduced / Sequestered(2020–2050)
# 4  Shift to Alternatives  CO2 EquivalentReduced / Sequestered(2020–2050)
#
#                                            short_def  \
# 0  Degraded farmland is often abandoned, but need...
# 1                                                NaN
# 2  Fluorinated gases are not the only refrigerant...
# 3  Bamboo rapidly sequesters carbon in biomass an...
# 4  Bicycles offer an alternative to cars and foss...
#
#                                              summary  \
# 0  Solution Summary*Around the world, farmers are...
# 1  Solution Summary*Cement is a vital source of s...
# 2  Solution SummaryThis is a new solution; a summ...
# 3  Solution Summary*In the Philippine creation st...
# 4  Solution Summary*Bicycles are on the rise as c...
#
#                                               impact  \
# 0  Impact: Currently, 0.4 billion hectares of far...
# 1                                                NaN
# 2  Impact: Pursuant to the Kigali Accord signed i...
# 3  Impact: Bamboo is planted on 33.52million hect...
# 4  Impact: In 2018, just under 3 percent of urban...
#
#                                         tech_summary
# 0  Project Drawdown describes abandoned farmland ...
# 1  Project Drawdown defines alternative cement as...
# 2  Project Drawdown defines alternative refrigera...
# 3  Project Drawdown defines bamboo production as ...
# 4  Project Drawdown defines bicycle infrastructur...

# %%
df_il_articles.head()
# Out:
#          category                                             sumary
# 0  climateScience                                                NaN
# 1  climateScience  This study links a framework for global and lo...
# 2  climateScience  Lab co-director Robert Kopp helped write the “...
# 3  climateScience  The GAO's new report draws heavily from two na...
# 4  climateScience  The impacts of heat waves in a warming climate...

# %%
df_il_article_content.head()
# Out:
#                                             abstract content  \
# 0  Heat stress harms human health, agriculture, a...     NaN
# 1  Mechanisms such as ice-shelf hydrofracturing a...     NaN
# 2  This assessment concludes, based on extensive ...     NaN
# 3                                                NaN     NaN
# 4  The impacts of heat waves in a warming climate...     NaN
#
#                                               header
# 0  Escalating Global Exposure to Compound Heat-Hu...
# 1  Evolving Understanding of Antarctic Ice-Sheet ...
# 2  Climate Science Special Report: Fourth Nationa...
# 3  Climate Change: Information on Potential Econo...
# 4  The Evolving Distribution of Relative Humidity...

# %%
# Testing function

test_df = pd.DataFrame()
test_df['content'] = df_dd_sectors['content']
# %time test_df['preprocessed'] = text_preprocessing(test_df['content'])
# Out:
# CPU times: user 1.5 s, sys: 113 ms, total: 1.62 s
# Wall time: 1.65 s

# %%
test_df.head(20)
# Out:
#                                              content  \
# 0  \nElectricity is particles in motion—a flow of...
# 1  \nHuman activity has transformed a significant...
# 2  \nFrom concrete to computers, cars to clothing...
# 3  \nGetting people or things from point A to poi...
# 4  \nInside is where most people are most of the ...
# 5  \nLand is a critical component of the climate ...
# 6  \nOurs is a water world. Though Earth has a la...
# 7  \nCan human engineering play a supporting role...
# 8  \nClimate and social systems are profoundly co...
#
#                                         preprocessed
# 0  [electricity, particle, motion—a, flow, electr...
# 1  [human, activity, transform, significant, frac...
# 2  [concrete, computer, car, clothe, industry, se...
# 3  [get, people, thing, point, point, b, perhaps,...
# 4  [inside, people, time, central, feature, human...
# 5  [land, critical, component, climate, system, a...
# 6  [water, world, though, earth, land-centric, na...
# 7  [human, engineering, play, support, role, natu...
# 8  [climate, social, system, profoundly, connect,...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Verifying most common words or combinations of words (ngrams) per category, in order to check if the pre-determined keywords seem valid for the dataset.

# %%
import matplotlib.pyplot as plt
from nltk.util import ngrams
from sklearn.feature_extraction.text import CountVectorizer
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %% [markdown]
# Let's review the columns in the dataset:

# %%
df_dd_sectors['preprocessed'] = test_df['preprocessed']

df_dd_sectors.head()
# Out:
#                             sector  \
# 0                      Electricity
# 1  Food, Agriculture, and Land Use
# 2                         Industry
# 3                   Transportation
# 4                        Buildings
#
#                                              content  \
# 0  \nElectricity is particles in motion—a flow of...
# 1  \nHuman activity has transformed a significant...
# 2  \nFrom concrete to computers, cars to clothing...
# 3  \nGetting people or things from point A to poi...
# 4  \nInside is where most people are most of the ...
#
#                                         preprocessed
# 0  [electricity, particle, motion—a, flow, electr...
# 1  [human, activity, transform, significant, frac...
# 2  [concrete, computer, car, clothe, industry, se...
# 3  [get, people, thing, point, point, b, perhaps,...
# 4  [inside, people, time, central, feature, human...

# %% [markdown]
# Now looking into the categories available:

# %%
set(df_dd_sectors['sector'])
# Out:
# {'Buildings',
#  'Coastal and Ocean Sinks',
#  'Electricity',
#  'Engineered Sinks',
#  'Food, Agriculture, and\xa0Land Use',
#  'Health and Education',
#  'Industry',
#  'Land Sinks',
#  'Transportation'}

# %%
category_count = df_dd_sectors['sector'].value_counts()

fig, ax = plt.subplots(figsize=(5,4))
sns.countplot(data = df_dd_sectors,
               x= 'sector',
               palette = "Set3",
               orient = 'h').set_xticklabels(ax.get_xticklabels(), rotation=90);
ax.set_title('Counts per Sector', fontsize= 16)
ax.set_ylabel('Counts', fontsize=14);
ax.set_xlabel('Sector', fontsize=14);

# %% [markdown]
# We see that most services are related to `Strengthening Communities` and the minority is related to `Emergency Preparedness`.
#
# Let's now look into the most common words associated to these community services.

# %%
#keywords 

def plot_top_keywords_barchart(text, title, n=1):
    stop=set(stopwords.words('english'))

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:20]

    top_n_keywords=_get_top_ngram(text,n)[:20]
    x,y=map(list,zip(*top_n_keywords))
    plt.figure(figsize=(10,10))
    plt.title(title)
    plt.xlabel("Keywords Frequency")
    plt.ylabel("Top 20 Keywords mentioned in Content")
    sns.barplot(x=y,y=x)

# %%
df_dd_sectors["preprocessed_text"] = [' '.join(map(str, l)) for l in df_dd_sectors['preprocessed']]

plot_top_keywords_barchart(df_dd_sectors['preprocessed_text'], 'Drawdown Sectors',1)

# %% [markdown]
# We can now compare how the keywords diverge across categories:

# %%
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Buildings']['preprocessed_text'], 'Buildings', 1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Coastal and Ocean Sinks']['preprocessed_text'], 'Coastal and Ocean Sinks', 1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Electricity']['preprocessed_text'], 'Electricity', 1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Engineered Sinks']['preprocessed_text'], 'Engineered Sinks', 1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']== 'Food, Agriculture, and\xa0Land Use']['preprocessed_text'], 'Food, Agriculture, and\xa0Land Use',1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Health and Education']['preprocessed_text'], 'Health and Education',1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Industry']['preprocessed_text'], 'Industry',1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Land Sinks']['preprocessed_text'], 'Land Sinks',1)
plot_top_keywords_barchart(df_dd_sectors[df_dd_sectors['sector']=='Transportation']['preprocessed_text'], 'Transportation',1)

# %% [markdown]
# We can summarize the most common words per category in wordcloud visualizations:

# %%
def wordcloud(sentence, title):

    stopword = set(STOPWORDS)
    wordcloud = WordCloud(background_color="white", max_words=2000, stopwords=stopword, 
                          contour_width=1).generate(' '.join(sentence))   

    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.title(title)
    plt.show()
    
wordcloud(df_raw['preprocessed_text'], 'Community Service NYC based on description')

# %%
wordcloud(df_raw[df_raw['category_desc']=='Education']['preprocessed_text'], 'Education')


wordcloud(df_raw[df_raw['category_desc']=='Emergency Preparedness']['preprocessed_text'], 'Emergency Preparedness')
wordcloud(df_raw[df_raw['category_desc']=='Environment']['preprocessed_text'], 'Environment')
wordcloud(df_raw[df_raw['category_desc']=='Health']['preprocessed_text'], 'Health')
wordcloud(df_raw[df_raw['category_desc']=='Helping Neighbors in Need']['preprocessed_text'], 'Helping Neighbors in Need')
wordcloud(df_raw[df_raw['category_desc']=='Strengthening Communities']['preprocessed_text'], 'Strengthening Communities')

# %%
#Bi-grams 

def plot_top_bigrams_barchart(text, title, n=2):
    stop=set(stopwords.words('english'))

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:20]

    top_n_bigrams=_get_top_ngram(text,n)[:20]
    x,y=map(list,zip(*top_n_bigrams))
    plt.figure(figsize=(10,10))
    plt.title(title)
    plt.xlabel("Bi-gram Frequency")
    plt.ylabel("Top 20 bi-grams mentioned in Service Description")
    sns.barplot(x=y,y=x)

# %% [markdown]
# Checking most common bi-grams for the whole dataset, i.e., most common combinations of 2 words:

# %%
plot_top_bigrams_barchart(df_raw['preprocessed_text'], 'NYC Community Service', 2)

# %%
plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Education']['preprocessed_text'], 'Education', 2)
plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Emergency Preparedness']['preprocessed_text'], 'Emergency Preparedness', 2)
plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Environment']['preprocessed_text'], 'Environment', 2)
plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Health']['preprocessed_text'], 'Health', 2)
plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Helping Neighbors in Need']['preprocessed_text'], 'Helping Neighbors in Need',2)
plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Strengthening Communities']['preprocessed_text'], 'Strengthening Communities',2)

# %%
#tri-grams

def plot_top_trigrams_barchart(text, title, n=3):
    stop=set(stopwords.words('english'))

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:20]

    top_n_bigrams=_get_top_ngram(text,n)[:20]
    x,y=map(list,zip(*top_n_bigrams))
    plt.figure(figsize=(10,10))
    plt.title(title)
    plt.xlabel("Tri-gram Frequency")
    plt.ylabel("Top 20 tri-grams mentioned in Service Description")
    sns.barplot(x=y,y=x)

# %%
plot_top_trigrams_barchart(df_raw['preprocessed_text'], 'NYC Community Service',3)

# %% [markdown]
# Now looking at top tri-grams per category:

# %%
plot_top_trigrams_barchart(df_raw[df_raw['category_desc']=='Education']['preprocessed_text'], 'Education', 3)
plot_top_trigrams_barchart(df_raw[df_raw['category_desc']=='Emergency Preparedness']['preprocessed_text'], 'Emergency Preparedness', 3)
plot_top_trigrams_barchart(df_raw[df_raw['category_desc']=='Environment']['preprocessed_text'], 'Environment', 3)
plot_top_trigrams_barchart(df_raw[df_raw['category_desc']=='Health']['preprocessed_text'], 'Health', 3)
plot_top_trigrams_barchart(df_raw[df_raw['category_desc']=='Helping Neighbors in Need']['preprocessed_text'], 'Helping Neighbors in Need',3)
plot_top_trigrams_barchart(df_raw[df_raw['category_desc']=='Strengthening Communities']['preprocessed_text'], 'Strengthening Communities',3)

# %% [markdown]
# One can easily see that the context of each category becomes clearer as more words are added to the ngrams. However, some expressions as `new york city` appear to be dominating across most of categories, indicating that they should be removed in the preprocessing stage.
#
# Next, we explore whether a new set of categories with pre-defined keywords can be more suitable for this dataset.

# %% [markdown]
# ## Assigning categories to services
#
# After preprocessing of the services dataframe, we have to now cross check the `summary` of each service opportunity to a list of pre-defined categories. For doing so, we first need to load and preprocessed the keywords in the categories as well.

# %% [markdown]
# **Step 1:** Loading Pre-defined Categories

# %%
categories = pd.read_excel('categories.xlsx', dtype=str).to_dict('list')

for key, value in categories.items():
    value = set(value)
    value.discard(np.nan)
    categories[key] = value

# Example    
categories.keys()

# %%
# Perform same preprocessing as for descriptions
for key, value in categories.items():
    words = set()
    for l in text_preprocessing(value, spelling=True):
        for x in l:
            words.add(x)
    categories[key] = words

categories['Travel']

# %%
# Checking number of categories

print(len(categories.keys()), list(categories.keys()))

# %% [markdown]
# Set the format of dataset to assing a category per row, given a summary:

# %%
for category in categories.keys():
    df_raw[category] = np.zeros(len(df_raw))

df_raw.info()

# %%
df_raw.head(10)

# %% [markdown]
# **Step 2:** Build a dictionary of the keywords of categories

# %%
dict_keywords = {}

for category in categories.keys():
    for keyword in categories[category]:
        if keyword not in dict_keywords.keys():
            dict_keywords[keyword] = [category]
        else:            
            dict_keywords[keyword].append(category)

# %%
# Displaying example of last keys in dictionary

print({k: dict_keywords[k] for k in list(dict_keywords)[-10:-1]})

# %%
# Number of words in dictionary

len(dict_keywords.keys())

# %%
# Check if there are still NaN values

np.nan in dict_keywords

# %% [markdown]
# **Step 3:** Matching words in summary with dictionary

# %%
# Scan each word in preprocessed description 

for index, row in df_raw.iterrows():
    for keyword in row['preprocessed']:

        # Check if word appears in dictionary
        if keyword in dict_keywords:
            #print('found keyword:', keyword)

            # Scan categories associated to keyword
            for category in dict_keywords[keyword]:
                # Add one to the counter of category in the description
                df_raw.at[index, category] += 1
                #print('inrease count to', descr_df.at[index, category])

# %%
df_raw.head(10)

# %% [markdown]
# **Step 4:** Post processing for categories encoding
#
# Setting all values of categories to `1` (belong) or `0` (don't belong):

# %%
# Remove description from list if it does not find a category
descr_train = df_raw[df_raw[categories.keys()].sum(axis=1) != 0.]

# Read top categories
for index, row in descr_train.iterrows():
    higher = row[categories.keys()].sort_values(ascending=False)
    nonzero = higher.index[higher.values > 0]
    
    # Reset categories to 0
    descr_train.loc[index, categories.keys()] = 0.

    # Set categories to 1
    descr_train.loc[index, nonzero] = 1.
    
descr_train.head()

# %%
import matplotlib.pyplot as plt

category_count = descr_train[categories.keys()].sum()

fig, ax = plt.subplots()
plt.bar(category_count.index, category_count)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# We can now compare 2 of the previous and new categories and see how their keywords diverge. First let's look into `Education` according to the new pre-defined category:

# %%
plot_top_bigrams_barchart(df_raw[df_raw['Education']==1]['preprocessed_text'], 'Education from pre-defined keywords', 2)

plot_top_bigrams_barchart(df_raw[df_raw['category_desc']=='Education']['preprocessed_text'], 'Education from original category',2)

# %% [markdown]
# and for the former one:

# %%
wordcloud(df_raw[df_raw['Education']==1]['preprocessed_text'], 'Education from pre-defined keywords')

wordcloud(df_raw[df_raw['category_desc']=='Education']['preprocessed_text'], 'Education from original category')

# %% [markdown]
# We can see that although the 2 categories represent `Education` for the same dataset, they differ significantly in terms of the key bi-grams representation, except by expressions such as `new york`.
#
# This simple exercise shows that the way keywords are defined in a categorization process (very common for building classifiers) can play an important role on the outcomes of your analysis. Further improvements of this analysis are presented below.

# %% [markdown]
# ## Further improvements ##
#
# * Add regular expression imposition in preprocessing
# Example:
# `title_df['title'] = title_df['title'].apply(lambda x: re.sub(r'[^\w\d\s\']+', '', x))`
#
# * Further explore new categories
#
# * Apply method for title
#
# * Build a classifier for categories
